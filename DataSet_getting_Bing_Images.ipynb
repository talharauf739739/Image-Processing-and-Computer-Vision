# %%
# !pip install bing_image-downloader

# %%
# !mkdir Sprite_can
# Out:
# mkdir: cannot create directory ‘Sprite_can’: File exists

# %%
from bing_image_downloader import downloader
downloader.download("sprite can", limit = 500, output_dir = 'Sprite_can')
# Out:
# [%] Downloading Images to /content/Sprite_can/sprite can
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 150 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.bristol.bs/wp-content/uploads/2016/06/Caribbean_Bottling_Co._Sprite_Can.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://ml0co0iaphua.i.optimole.com/JAgwYyw-sfsHHfXb/w:1000/h:1000/q:auto/https://gharstuff.com/wp-content/uploads/2018/12/Sprite-Soft-Drink-Can-300ml.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://static1.squarespace.com/static/52536652e4b007332ef4ecf4/t/576afa485016e1c12431564e/1466628690989/
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.ebayimg.com/images/g/z2gAAOSwrW9dm4f9/s-l400.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.ebayimg.com/images/g/Nz8AAOSwaldevCnI/s-l640.jpg
# [%] File Downloaded !
#
# ...
