# %%
#!pip install opencv-python


import os
#import cv2 as cv
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import glob as gb
path="/content/drive/MyDrive/10_20_21_dataset"
main_folder = os.listdir(path)
#picture = os.listdir(main_folder)
img_list = []
binary_list = []
folder_belonging = []
folder_label=[]
for n in range(0,len(main_folder)):
  if main_folder[n]==".ipynb_checkpoints":
    #print(main_folder[i])
    continue
  pics = path + "/" + main_folder[n]
  for m in os.listdir(pics):
    x = pics + "/" + m
    imagess = cv2.imread(x)
    img_list.append(imagess)
    folder_belonging.append(pics)
    print(pics)
    folder_label.append(main_folder[n])
#print(path)
print(folder_label)
#print(img_list)
# Out:
# /content/drive/MyDrive/10_20_21_dataset/messy
# /content/drive/MyDrive/10_20_21_dataset/messy
# /content/drive/MyDrive/10_20_21_dataset/messy
# /content/drive/MyDrive/10_20_21_dataset/messy
# /content/drive/MyDrive/10_20_21_dataset/messy
# /content/drive/MyDrive/10_20_21_dataset/messy
# /content/drive/MyDrive/10_20_21_dataset/messy
# /content/drive/MyDrive/10_20_21_dataset/messy
# /content/drive/MyDrive/10_20_21_dataset/messy
# /content/drive/MyDrive/10_20_21_dataset/messy
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# /content/drive/MyDrive/10_20_21_dataset/fruit
# ['messy', 'messy', 'messy', 'messy', 'messy', 'messy', 'messy', 'messy', 'messy', 'messy', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit', 'fruit']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img_list
# Out:
# [array([[[177, 191, 201],
#          [186, 200, 210],
#          [192, 207, 220],
#          ...,
#          [127, 146, 161],
#          [128, 147, 162],
#          [129, 148, 163]],
#
#         [[180, 195, 203],
#          [186, 200, 208],
#          [194, 210, 222],
#          ...,
#          [127, 146, 161],
#          [128, 147, 162],
#          [129, 148, 163]],
#
#         [[185, 200, 208],
#          [184, 197, 206],
#          [192, 208, 219],
#          ...,
#          [127, 146, 161],
#          [127, 146, 161],
#          [128, 147, 162]],
#
#         ...,
#
#         [[ 82,  84,  84],
#          [ 82,  83,  84],
#          [ 82,  84,  84],
#          ...,
#          [ 70,  80,  89],
#          [ 70,  80,  89],
#          [ 70,  80,  90]],
#
#         [[131, 131, 131],
#          [131, 131, 131],
#          [131, 131, 131],
#          ...,
#          [131, 131, 131],
#          [131, 131, 131],
#          [131, 131, 131]],
#
#         [[192, 192, 192],
#          [192, 192, 192],
#          [192, 192, 192],
#          ...,
#          [192, 192, 192],
#          [192, 192, 192],
#          [192, 192, 192]]], dtype=uint8), array([[[157, 160, 187],
#          [143, 149, 179],
#          [145, 152, 180],
#          ...,
#          [ 47,  55,  52],
#          [ 44,  50,  48],
#          [ 41,  43,  43]],
#
#         [[160, 162, 189],
#          [145, 151, 184],
#          [145, 153, 185],
#          ...,
#          [ 44,  51,  48],
#          [ 36,  43,  40],
#          [ 32,  37,  35]],
#
#         [[163, 165, 192],
#          [148, 154, 187],
#          [143, 153, 186],
#          ...,
#          [ 29,  33,  33],
#          [ 29,  35,  33],
#          [ 34,  40,  38]],
#
#         ...,
#
#         [[223, 198, 166],
#          [226, 204, 173],
#          [227, 205, 177],
#          ...,
#          [ 85,  82,  73],
#          [138, 126, 118],
#          [208, 192, 187]],
#
#         [[222, 197, 165],
#          [228, 206, 174],
#          [233, 213, 185],
#          ...,
#          [ 84,  82,  72],
#          [114, 105,  96],
#          [191, 176, 170]],
#
#         [[224, 199, 166],
#          [236, 213, 183],
#          [240, 220, 192],
#          ...,
#          [ 97,  96,  85],
#          [106,  97,  88],
#          [171, 156, 150]]], dtype=uint8), array([[[108, 199, 253],
#          [111, 201, 253],
#          [115, 202, 254],
#          ...,
#          [ 39,  36,  50],
#          [ 38,  38,  44],
#          [ 50,  45,  45]],
#
#         [[111, 197, 253],
#          [109, 193, 252],
#          [105, 188, 250],
#          ...,
#          [ 36,  36,  50],
#          [ 39,  39,  44],
#          [ 49,  44,  44]],
#
#         [[112, 189, 253],
#          [103, 181, 250],
#          [ 96, 172, 245],
#          ...,
#          [ 38,  39,  52],
#          [ 40,  40,  45],
#          [ 49,  44,  45]],
#
#         ...,
#
#         [[ 56,  96, 127],
#          [ 54,  92, 126],
#          [ 51,  89, 122],
#          ...,
#          [ 39,  75, 104],
#          [ 36,  72, 102],
#          [ 29,  67,  96]],
#
#         [[ 51,  90, 122],
#          [ 51,  90, 122],
#          [ 49,  88, 119],
#          ...,
#          [ 32,  69, 100],
#          [ 32,  69,  99],
#          [ 37,  74, 102]],
#
#         [[ 51,  89, 121],
#          [ 53,  92, 123],
#          [ 54,  96, 124],
#          ...,
#          [ 41,  79, 111],
#          [ 38,  76, 107],
#          [ 44,  81, 109]]], dtype=uint8), array([[[120, 166, 177],
#          [118, 161, 174],
#          [119, 159, 173],
#          ...,
#          [178, 215, 207],
#          [181, 218, 210],
#          [184, 221, 213]],
#
#         [[121, 167, 178],
#          [116, 159, 172],
#          [118, 160, 174],
#          ...,
#          [179, 216, 208],
#          [181, 218, 210],
#          [182, 219, 211]],
#
#         [[122, 168, 179],
#          [117, 160, 173],
#          [121, 163, 176],
#          ...,
#          [181, 218, 210],
#          [182, 219, 211],
#          [181, 218, 210]],
#
#         ...,
#
#         [[ 41,  26,  48],
#          [ 41,  26,  48],
#          [ 39,  24,  45],
#          ...,
#          [ 42,  36,  95],
#          [ 50,  43, 104],
#          [ 51,  43, 106]],
#
#         [[ 51,  35,  59],
#          [ 38,  22,  46],
#          [ 41,  26,  48],
#          ...,
#          [ 32,  26,  86],
#          [ 41,  34,  95],
#          [ 49,  42, 104]],
#
#         [[ 49,  33,  56],
#          [ 40,  24,  47],
#          [ 41,  25,  49],
#          ...,
#          [ 34,  28,  87],
#          [ 35,  29,  89],
#          [ 38,  31,  93]]], dtype=uint8), array([[[219, 216, 212],
#          [219, 216, 212],
#          [219, 216, 212],
#          ...,
#          [121, 126, 117],
#          [139, 143, 138],
#          [185, 189, 184]],
#
#         [[219, 216, 212],
#          [219, 216, 212],
#          [219, 216, 212],
#          ...,
#          [192, 197, 188],
#          [187, 191, 185],
#          [192, 196, 191]],
#
#         [[219, 216, 212],
#          [219, 216, 212],
#          [219, 216, 212],
#          ...,
#          [199, 202, 193],
#          [184, 186, 180],
#          [200, 202, 196]],
#
#         ...,
#
#         [[114, 162, 180],
#          [115, 163, 181],
#          [119, 165, 183],
#          ...,
#          [ 78, 131, 117],
#          [104, 159, 142],
#          [ 55, 110,  93]],
#
#         [[112, 160, 178],
#          [116, 164, 182],
#          [119, 165, 183],
#          ...,
#          [ 64, 119, 104],
#          [110, 165, 148],
#          [ 78, 133, 116]],
#
#         [[112, 160, 178],
#          [116, 164, 182],
#          [119, 165, 183],
#          ...,
#          [ 65, 120, 105],
#          [113, 168, 151],
#          [ 89, 144, 127]]], dtype=uint8), array([[[ 69,  80,  75],
#          [ 76,  82,  75],
#          [ 73,  80,  73],
#          ...,
#          [ 94,  97,  97],
#          [ 93,  96, 100],
#          [ 93,  97,  98]],
#
#         [[ 66,  79,  78],
#          [ 69,  81,  81],
#          [ 68,  80,  80],
#          ...,
#          [ 96,  97,  96],
#          [ 99,  96,  94],
#          [ 99,  97,  92]],
#
#         [[ 72,  81,  75],
#          [ 74,  80,  79],
#          [ 75,  82,  81],
#          ...,
#          [ 96,  97,  98],
#          [ 97,  98,  95],
#          [ 96,  97,  95]],
#
#         ...,
#
#         [[ 13,   7,  12],
#          [ 11,   8,  11],
#          [ 12,   8,  10],
#          ...,
#          [ 43,  30,  37],
#          [ 42,  31,  39],
#          [ 53,  38,  46]],
#
#         [[ 13,   5,  17],
#          [ 12,   7,  16],
#          [ 13,   7,  16],
#          ...,
#          [ 56,  33,  48],
#          [ 54,  33,  48],
#          [ 58,  34,  50]],
#
#         [[ 12,   4,  18],
#          [ 12,   6,  16],
#          [ 13,   7,  17],
#          ...,
#          [ 53,  28,  49],
#          [ 57,  33,  51],
#          [ 57,  30,  49]]], dtype=uint8), array([[[128, 136, 139],
#          [128, 137, 140],
#          [128, 137, 140],
#          ...,
#          [121, 124, 128],
#          [120, 123, 127],
#          [121, 122, 126]],
#
#         [[129, 136, 139],
#          [129, 137, 140],
#          [128, 137, 140],
#          ...,
#          [121, 124, 128],
#          [122, 125, 129],
#          [123, 124, 128]],
#
#         [[130, 137, 140],
#          [129, 137, 140],
#          [128, 137, 140],
#          ...,
#          [123, 127, 128],
#          [120, 124, 125],
#          [121, 123, 124]],
#
#         ...,
#
#         [[117, 114, 115],
#          [114, 113, 114],
#          [112, 113, 114],
#          ...,
#          [ 65,  60,  64],
#          [ 65,  59,  63],
#          [ 68,  61,  66]],
#
#         [[117, 116, 116],
#          [116, 116, 116],
#          [113, 114, 115],
#          ...,
#          [ 92,  85,  86],
#          [ 94,  83,  85],
#          [ 87,  76,  79]],
#
#         [[121, 120, 119],
#          [118, 118, 118],
#          [116, 117, 118],
#          ...,
#          [113, 104, 106],
#          [116, 105, 107],
#          [112,  99, 103]]], dtype=uint8), array([[[247, 253, 252],
#          [247, 253, 252],
#          [246, 252, 251],
#          ...,
#          [134, 141, 152],
#          [130, 141, 153],
#          [129, 139, 151]],
#
#         [[249, 255, 254],
#          [250, 255, 254],
#          [249, 254, 253],
#          ...,
#          [134, 143, 153],
#          [130, 143, 151],
#          [128, 139, 150]],
#
#         [[251, 255, 255],
#          [251, 255, 255],
#          [251, 255, 254],
#          ...,
#          [131, 144, 152],
#          [130, 143, 151],
#          [127, 142, 149]],
#
#         ...,
#
#         [[ 33,  60, 102],
#          [ 31,  61, 101],
#          [ 36,  61, 102],
#          ...,
#          [ 10,  63, 125],
#          [ 13,  63, 125],
#          [ 16,  63, 126]],
#
#         [[ 34,  61, 102],
#          [ 35,  63, 102],
#          [ 38,  64, 104],
#          ...,
#          [  9,  59, 117],
#          [ 10,  57, 118],
#          [ 12,  60, 120]],
#
#         [[ 34,  64, 104],
#          [ 32,  63,  99],
#          [ 37,  61,  96],
#          ...,
#          [ 12,  62, 120],
#          [ 14,  62, 121],
#          [ 16,  63, 123]]], dtype=uint8), array([[[ 25,  30,  24],
#          [ 35,  43,  34],
#          [ 46,  59,  47],
#          ...,
#          [  3,  46, 108],
#          [  5,  46, 108],
#          [  3,  43, 106]],
#
#         [[ 34,  38,  35],
#          [ 43,  51,  44],
#          [ 59,  72,  62],
#          ...,
#          [  4,  45, 107],
#          [  1,  39, 101],
#          [  5,  42, 106]],
#
#         [[ 41,  44,  43],
#          [ 52,  59,  55],
#          [ 72,  83,  76],
#          ...,
#          [  4,  50, 111],
#          [  5,  49, 110],
#          [  6,  48, 111]],
#
#         ...,
#
#         [[  5,   6,   4],
#          [  4,   5,   3],
#          [  4,   5,   3],
#          ...,
#          [120, 143, 203],
#          [116, 145, 201],
#          [111, 146, 198]],
#
#         [[  6,   7,   5],
#          [  6,   7,   5],
#          [  5,   6,   4],
#          ...,
#          [107, 136, 196],
#          [107, 138, 194],
#          [103, 136, 189]],
#
#         [[  6,   7,   5],
#          [  8,   9,   7],
#          [  5,   6,   4],
#          ...,
#          [ 99, 129, 182],
#          [104, 131, 181],
#          [107, 133, 179]]], dtype=uint8), array([[[ 67,  70,  75],
#          [ 69,  72,  77],
#          [ 71,  74,  79],
#          ...,
#          [145, 164, 179],
#          [144, 164, 179],
#          [144, 165, 180]],
#
#         [[ 67,  70,  75],
#          [ 69,  72,  77],
#          [ 74,  77,  82],
#          ...,
#          [147, 166, 181],
#          [145, 165, 180],
#          [144, 165, 180]],
#
#         [[ 67,  70,  75],
#          [ 67,  70,  75],
#          [ 70,  73,  78],
#          ...,
#          [147, 166, 181],
#          [146, 166, 181],
#          [146, 167, 182]],
#
#         ...,
#
#         [[255, 255, 255],
#          [253, 254, 254],
#          [254, 252, 251],
#          ...,
#          [ 80,  91,  99],
#          [ 80,  91,  99],
#          [ 80,  90, 100]],
#
#         [[255, 255, 255],
#          [254, 254, 255],
#          [252, 254, 254],
#          ...,
#          [ 80,  91,  99],
#          [ 78,  89,  97],
#          [ 80,  90, 100]],
#
#         [[254, 254, 254],
#          [255, 254, 255],
#          [253, 255, 255],
#          ...,
#          [ 79,  90,  98],
#          [ 80,  91,  99],
#          [ 79,  89,  99]]], dtype=uint8), array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8), array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8), array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8), array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8), array([[[245, 247, 247],
#          [245, 247, 247],
#          [244, 246, 246],
#          ...,
#          [244, 244, 244],
#          [244, 244, 244],
#          [244, 244, 244]],
#
#         [[244, 246, 246],
#          [244, 246, 246],
#          [244, 246, 246],
#          ...,
#          [244, 244, 244],
#          [244, 244, 244],
#          [244, 244, 244]],
#
#         [[244, 246, 246],
#          [244, 246, 246],
#          [243, 245, 245],
#          ...,
#          [242, 244, 244],
#          [242, 244, 244],
#          [242, 244, 244]],
#
#         ...,
#
#         [[244, 249, 248],
#          [245, 250, 249],
#          [245, 250, 249],
#          ...,
#          [240, 245, 244],
#          [241, 246, 245],
#          [241, 246, 245]],
#
#         [[244, 249, 248],
#          [245, 250, 249],
#          [245, 250, 249],
#          ...,
#          [241, 246, 245],
#          [241, 246, 245],
#          [242, 247, 246]],
#
#         [[244, 249, 248],
#          [246, 251, 250],
#          [245, 250, 249],
#          ...,
#          [241, 246, 245],
#          [241, 246, 245],
#          [242, 247, 246]]], dtype=uint8), array([[[ 69,   2, 137],
#          [ 70,   2, 139],
#          [ 71,   3, 142],
#          ...,
#          [ 69,  67,  36],
#          [ 69,  67,  36],
#          [ 69,  68,  34]],
#
#         [[ 69,   2, 137],
#          [ 69,   3, 138],
#          [ 71,   3, 142],
#          ...,
#          [ 68,  66,  35],
#          [ 68,  67,  33],
#          [ 68,  68,  32]],
#
#         [[ 67,   2, 135],
#          [ 66,   3, 137],
#          [ 69,   2, 141],
#          ...,
#          [ 65,  63,  32],
#          [ 65,  65,  29],
#          [ 65,  66,  27]],
#
#         ...,
#
#         [[ 47,  54,   3],
#          [ 46,  53,   2],
#          [ 46,  52,   3],
#          ...,
#          [ 42,  70,  50],
#          [ 38,  66,  46],
#          [ 35,  63,  43]],
#
#         [[ 47,  55,   2],
#          [ 47,  54,   3],
#          [ 46,  52,   3],
#          ...,
#          [ 45,  73,  53],
#          [ 41,  69,  49],
#          [ 39,  67,  47]],
#
#         [[ 48,  56,   3],
#          [ 47,  54,   3],
#          [ 46,  52,   3],
#          ...,
#          [ 46,  74,  54],
#          [ 44,  72,  52],
#          [ 41,  69,  49]]], dtype=uint8), array([[[ 24,  25,  35],
#          [ 24,  25,  35],
#          [ 23,  24,  34],
#          ...,
#          [ 70, 196, 160],
#          [ 69, 194, 155],
#          [ 67, 189, 151]],
#
#         [[ 24,  25,  35],
#          [ 24,  25,  35],
#          [ 23,  24,  34],
#          ...,
#          [ 76, 200, 164],
#          [ 75, 197, 161],
#          [ 72, 194, 156]],
#
#         [[ 24,  25,  35],
#          [ 24,  25,  35],
#          [ 24,  25,  35],
#          ...,
#          [ 84, 204, 170],
#          [ 80, 200, 166],
#          [ 77, 197, 162]],
#
#         ...,
#
#         [[ 67,  53,  54],
#          [ 56,  48,  48],
#          [ 45,  50,  48],
#          ...,
#          [ 16, 142, 120],
#          [ 18, 142, 120],
#          [ 18, 142, 120]],
#
#         [[ 68,  52,  53],
#          [ 59,  49,  49],
#          [ 46,  47,  45],
#          ...,
#          [ 12, 138, 116],
#          [ 14, 138, 116],
#          [ 15, 139, 117]],
#
#         [[ 65,  49,  50],
#          [ 58,  48,  48],
#          [ 45,  43,  42],
#          ...,
#          [  9, 135, 113],
#          [ 11, 135, 113],
#          [ 12, 136, 114]]], dtype=uint8), array([[[209, 212, 203],
#          [209, 212, 203],
#          [209, 212, 203],
#          ...,
#          [179, 179, 179],
#          [179, 179, 179],
#          [179, 179, 179]],
#
#         [[209, 212, 203],
#          [209, 212, 203],
#          [209, 212, 203],
#          ...,
#          [172, 172, 172],
#          [172, 172, 172],
#          [172, 172, 172]],
#
#         [[209, 212, 203],
#          [209, 212, 203],
#          [209, 212, 203],
#          ...,
#          [165, 165, 165],
#          [165, 165, 165],
#          [165, 165, 165]],
#
#         ...,
#
#         [[186, 183, 169],
#          [186, 183, 169],
#          [186, 183, 169],
#          ...,
#          [101,  95,  88],
#          [101,  95,  88],
#          [101,  95,  88]],
#
#         [[190, 187, 173],
#          [190, 187, 173],
#          [190, 187, 173],
#          ...,
#          [106, 100,  93],
#          [106, 100,  93],
#          [106, 100,  93]],
#
#         [[194, 191, 177],
#          [194, 191, 177],
#          [194, 191, 177],
#          ...,
#          [116, 110, 103],
#          [116, 110, 103],
#          [116, 110, 103]]], dtype=uint8), array([[[236, 236, 236],
#          [236, 236, 236],
#          [236, 236, 236],
#          ...,
#          [221, 221, 221],
#          [221, 221, 221],
#          [221, 221, 221]],
#
#         [[236, 236, 236],
#          [236, 236, 236],
#          [236, 236, 236],
#          ...,
#          [221, 221, 221],
#          [221, 221, 221],
#          [221, 221, 221]],
#
#         [[236, 236, 236],
#          [236, 236, 236],
#          [236, 236, 236],
#          ...,
#          [221, 221, 221],
#          [221, 221, 221],
#          [221, 221, 221]],
#
#         ...,
#
#         [[221, 221, 221],
#          [221, 221, 221],
#          [221, 221, 221],
#          ...,
#          [219, 206, 198],
#          [219, 207, 197],
#          [219, 207, 197]],
#
#         [[221, 221, 221],
#          [221, 221, 221],
#          [221, 221, 221],
#          ...,
#          [219, 206, 198],
#          [219, 207, 197],
#          [219, 207, 197]],
#
#         [[221, 221, 221],
#          [221, 221, 221],
#          [221, 221, 221],
#          ...,
#          [218, 205, 197],
#          [218, 206, 196],
#          [218, 206, 196]]], dtype=uint8), array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [216, 202, 214],
#          [216, 202, 214],
#          [216, 202, 214]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [217, 203, 215],
#          [217, 203, 215],
#          [217, 203, 215]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [213, 199, 211],
#          [213, 199, 211],
#          [213, 199, 211]]], dtype=uint8), array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         ...,
#
#         [[ 72,  50,  52],
#          [ 72,  50,  52],
#          [ 72,  50,  52],
#          ...,
#          [ 72,  50,  52],
#          [ 72,  50,  52],
#          [ 72,  50,  52]],
#
#         [[ 71,  50,  52],
#          [ 71,  50,  52],
#          [ 71,  50,  52],
#          ...,
#          [ 72,  50,  52],
#          [ 72,  50,  52],
#          [ 72,  50,  52]],
#
#         [[ 71,  50,  52],
#          [ 71,  50,  52],
#          [ 71,  50,  52],
#          ...,
#          [ 72,  50,  52],
#          [ 72,  50,  52],
#          [ 72,  50,  52]]], dtype=uint8), array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8)]

# %%
import cv2
from google.colab.patches import cv2_imshow


for i in range(0,len(img_list)):
  #image = cv2.imread(imagess)
  resize= cv2.resize(imagess, (300,300))
  ret, bw_img = cv2.threshold(imagess,127,255,cv2.THRESH_BINARY)
  binary_list.append(bw_img)

# %%
X = binary_list
y = folder_label
cv2_imshow(binary_list[1])
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3ED938F710>

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)


y_train = np.array(y_train)
y_test = np.array(y_test)
print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (19, 224, 224, 3)
# y_train shape (19,)
# y_test shape (3,)

# %%
X_train = X_train.reshape(len(X_train), X[1].size)
X_test = X_test.reshape(len(X_test), X[1].size)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
#Import knearest neighbors Classifier model
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=3)

#Train the model using the training sets
knn.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = knn.predict(X_test)




#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6666666666666666
